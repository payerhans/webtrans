# %%
from bs4 import BeautifulSoup
import urllib3
import certifi

# %%
url="https://man.liquidfiles.com/userguide.html"
c=urllib3.PoolManager(cert_reqs='CERT_REQUIRED', ca_certs=certifi.where())

# %%
content = c.request('GET', url)

# %%
soup = BeautifulSoup(content.data)

# %%
text = soup.body.get_text()
text
# Out:
# '\n\n\n\n\n\n\nToggle navigation\n\n\n\n\n\n\n\n\n\n\n\n\nSearch\n\nUser Guide\nInstall\nFAQ\n\nTopics \n\nINSTALLATION & LICENSING\n\nInstallation & Planning\n\nIs LiquidFiles for me?\nPlanning the Deployment\nSystem Requirements &Performance Optimization\nPhysical Server /ISO Installation\nVMware ESX Installation\nAmazon EC2 Installation\nMicrosoft Azure Installation\nMicrosoft Hyper-V Installation\nCitrix Xen Installation\nGetting Started\n\n\n\nUpdating\n\nUpdating LiquidFiles\nUpdating from LiquidFilesv2.x to v3.x\n\n\n\nMove Server\n\nMoving to a new Server\n\n\n\nLicensing\n\nLicense Overview\nPayment Options\nLicense Renewal\nLicense Upgrades\nDev/test/staging system\nLegacy Licenses and LiquidFiles\n\n\n\nRelease Notes\n\nRelease Notes v3.3.x\nRelease Notes v3.2.x\nRelease Notes v3.1.x\nRelease Notes v3.0.x\nRelease Notes v2.6.x\nRelease Notes v2.5.x\nRelease Notes v2.4.x\nRelease Notes v2.3.x\nRelease Notes v2.2.x\nRelease Notes v2.1.x\nRelease Notes v2.0.x\nRelease Notes v1.8.x\nRelease Notes v1.7.x\nRelease Notes v1.6.x\nRelease Notes v1.5.x\nRelease Notes v1.4.x\nRelease Notes v1.3.x\nRelease Notes v1.2.x\nRelease Notes v1.1.x\nRelease Notes v1.0.x\n\n\nCONFIGURATION\n\nFeature Overview\n\nFiledrops\nEmaildrops\nFTPdrops & FTPdirs\n\n\n\nGeneral info\n\nAbout LiquidFiles Support\nLocal vs External Users\nSecurity Information\nBrowser Support\nFile Size Limits\n\n\n\nFiledrops\n\nSystem Filedrops\nUser Filedrops\nFiledrop Custom Fields\nPre-Fill Filedrop Parameters\n\n\n\nConfiguration\n\nAutomatically AssignUsers to Groups\nWorking with Groups\nLDAP Configuration\n\n\n\nBranding\n\nBranding the Home Page\nCustomizing the Header\nCustomizing the Footer\nFavicon\nCustom stylesheet peruser/group\nCustomizing the initand error pages\nChanging the help page\nDisplaying different contentbased on locale\nStylesheet and Javascriptoverrides\nChanging any text on anyvisible page or email\nExamples\n\n\nSECURITY,AUTHENTICATION &AUTHORIZATION\n\nSecurity\n\nGeneral Security Information\nAntivirus Scanning\nCustom file scanning using Actionscript\nWeb server redirectconfiguration\nUnderstanding HSTS\nFrequent Responses aftersecurity reviews\nSystem Vulnerabilities\nCompliance\n\n\n\nAuthentication &Authorization\n\nPassword Policy\nAdvanced Custom PasswordValidation with Actionscript\nTwo Factor Authentication\nSingle Sign-On (SSO)with pre shared key\nSingle Sign-On using SAML\nSSO SAML2.0 on W2008 R2server and LiquidFiles\nSSO SAML2.0 on W2012 R2server and LiquidFiles\nSSO SAML2.0 in Azureserver and LiquidFiles\nDownload Authentication\nDownload accesspermission (authorization)\n\n\nAPI\n\nGeneral API\n\nBasics\nIntroduction and Authentication\nHistory and Versions\nRetrieve API key\nRetrieve any users API key\nClient Info Request\nAttachments\nAttachment (File Upload) API\nAttachment Chunks\nDelete Attachments\nMessages\nSecure Messages\nList Sent Messages\nValidate Recipients API\nList Messages andDownload Attachments\nFiledrop\nFiledrop API\nFile Requests\nFile Request API\nFileLink\nFileLink API\nDownload\nDownload Log API\nOther\nDevelopment (C#, .NET, Java, ...)\nLiquidFiles v2.x XML API\nShare: List\nShare: View\nFolder: View\nFolder: Create\nFolder: Delete\nFolder: Rename\nFolder: Move\nFile: View\nFile: Download\nFile: Upload\nFile: Delete\nFile: Rename\nFile: Move\nFile/Folder: Restore\n\n\n\nAdmin API\n\nIntroduction to the Admin API\nUser Admin API\nGroup Admin API\nFiledrop Admin API\nPool Admin API\nCreate Share API\nList/View Shares API\nDelete Shares API\nAdd/Update Share Access API\nRemove Share Access API\n\n\nSYSTEM\n\nGeneral System\n\nNetwork & Firewallconfiguration\nDNS\nHTTP/HTTPS redirectconfiguration\nReverse Proxy Configuration\nLogging in to theSystem Console\n\n\n\nCertificates\n\nOverview\nCertificate Install Guide\nLet\'s Encrypt\nGenerate CSR\nGenerate Custom CSR\nWildcard Certificates\nTroubleshooting\nBackup & Restore Certificates\nConvert SSL formats\nGeneral Information\n\n\n\nDisk and Stora ...

# %%
with open('output.txt', 'w') as t:
    for line in text:
        t.write(line)

# %%
print(soup.body.prettify)
# Out:
# <bound method Tag.prettify of <body class="page_layout_default page_userguide" data-spy="scroll" data-target=".scrollspy">
# <header>
# <nav class="navbar navbar-default navbar-fixed-top">
# <div class="container-fluid">
# <!-- Brand and toggle get grouped for better mobile display -->
# <div class="navbar-header">
# <button aria-expanded="false" class="navbar-toggle collapsed" data-target="#main-navbar" data-toggle="collapse" type="button">
# <span class="sr-only">Toggle navigation</span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# </button>
# <a class="navbar-brand" href="/"><img alt="LiquidFiles Documentation" height="25" src="/assets/images/header_logo-338e20fa3f38c137f204e241769f9d2e8640c7e4e779acadb5d453fb96267cf1.png" width="312"/></a>
# </div>
# <div class="collapse navbar-collapse" id="main-navbar">
# <ul class="nav navbar-nav pull-right">
# </ul><form action="/search.html" class="navbar-form navbar-left hidden-sm hidden-xs" method="get" role="search">
# <div class="form-group">
# <input class="form-control" id="navbar_search_field" name="q" placeholder="Search" type="text"/>
# </div>
# <button class="btn btn-default" type="submit">Search</button>
# </form>
# <li id="menu_userguide"><a href="/userguide.html">User Guide</a></li>
# <li id="menu_install"><a href="/install/">Install</a></li>
# <li id="menu_faq"><a href="/faq.html">FAQ</a></li>
# <li class="dropdown pull-left" id="menu_configuration" style="margin-right: 30px;">
# <a class="dropdown-toggle" data-toggle="dropdown" href="#">Topics <b class="caret"></b></a>
# <ul aria-labelledby="dropdownMenu" class="dropdown-menu dropdown-menu-right multi-level" role="menu">
# <li class="dropdown-header">INSTALLATION &amp; LICENSING</li>
# <li class="dropdown-submenu">
# <a href="#" tabindex="-1">Installation &amp; Planning</a>
# <ul class="dropdown-menu">
# <li><a href="/install/is_liquidfiles_for_me.html">Is LiquidFiles for me?</a></li>
# <li><a href="/install/planning.html">Planning the Deployment</a></li>
# <li><a href="/install/system_requirements.html">System Requirements &amp;<br/>Performance Optimization</a></li>
# <li><a href="/install/iso.html">Physical Server /<br/>ISO Installation</a></li>
# <li><a href="/install/esx.html">VMware ESX Installation</a></li>
# <li><a href="/install/ec2.html">Amazon EC2 Installation</a></li>
# <li><a href="/install/azure.html">Microsoft Azure Installation</a></li>
# <li><a href="/install/hyperv.html">Microsoft Hyper-V Installation</a></li>
# <li><a href="/install/xen.html">Citrix Xen Installation</a></li>
# <li><a href="/install/getting_started.html">Getting Started</a></li>
# </ul>
# </li>
# <li class="dropdown-submenu">
# <a href="#" tabindex="-1">Updating</a>
# <ul class="dropdown-menu">
# <li><a href="/install/update.html">Updating LiquidFiles</a></li>
# <li><a href="/install/update_v3.html">Updating from LiquidFiles<br/>v2.x to v3.x</a></li>
# </ul>
# </li>
# <li class="dropdown-submenu">
# <a href="#" tabindex="-1">Move Server</a>
# <ul class="dropdown-menu">
# <li><a href="/install/move_server.html">Moving to a new Server</a></li>
# </ul>
# </li>
# <li class="dropdown-submenu">
# <a href="#" tabindex="-1">Licensing</a>
# <ul class="dropdown-menu">
# <li><a href="/license/overview.html">License Overview</a></li>
# <li><a href="/license/payment_options.html">Payment Options</a></li>
# <li><a href="/license/license_renewal.html">License Renewal</a></li>
# <li><a href="/license/license_upgrades.html">License Upgrades</a></li>
# <li><a href="/license/test_staging_system.html">Dev/test/staging system</a></li>
# <li><a href="/legacy/licenses.html">Legacy Licenses and LiquidFiles</a></li>
# </ul>
# </li>
# <li class="dropdown-submenu">
# <a href="#" tabindex="-1">Release Notes</a>
# <ul class="dropdown-menu">
# <li class="rl33"><a href="/release_notes/version_3-3-x.html">Release Notes v3.3.x</a></li>
# <li class="rl32"><a href="/release_notes/version_3-2-x.html">Release Notes v3.2.x</a></li>
# <li class="rl31"><a href="/release_notes/version_3-1-x.html">Release Notes v3.1.x</a></li>
# <li class="rl30"><a href="/release_notes/version_3-0-x.html">Release Notes v3.0.x</a></li>
# <li class="rl26"><a href="/release_notes/version_2-6-x.html">Release Notes v2.6.x</a></li>
# <li class="rl25"><a href="/release_notes/version_2-5-x.html">Release Notes v2.5.x</a></li>
# <li class="rl24"><a href="/release_notes/version_2-4-x.html">Release Notes v2.4.x</a></li>
# <li class="rl23"><a href="/release_notes/version_2-3-x.html">Release Notes v2.3.x</a></li>
# <li class="rl22"><a href="/release_notes/version_2-2-x.html">Release Notes v2.2.x</a></li>
# <li class="rl21"><a href="/release_notes/version_2-1-x.html">Release Notes v2.1.x</a></li>
# <li class="rl20"><a href="/release_notes/version_2-0-x.html">Release Notes v2.0.x</a></li>
# <li class="rl18"><a href="/release_notes/version_1-8-x.html">Release Notes v1.8.x</a></li>
# <li class="rl17"><a href="/release_notes/version_1-7-x.html">Release Notes v1.7.x</a></li>
# <li class="rl16"><a href="/release_notes/version_1-6-x.html">Release Notes v1.6.x</a></li>
# <li class="rl15"><a href="/release_notes/version_1-5-x.html">Release Notes v1.5.x</a></li>
# <li class="rl14"><a href="/release_notes/version_1-4-x.html">Release Notes v1.4.x</a></li>
# <li class="rl13"><a href="/release_notes/version_1-3-x.html">Release Notes v1.3.x</a></li>
# <li class="rl12"><a href="/release_notes/version_1-2-x.html">Release Notes v1.2.x</a></li>
# <li class="rl11"><a href="/release_notes/version_1-1-x.html">Release Notes v1.1.x</a></li>
# <li class="rl10"><a href="/release_notes/version_1-0-x.html">Release Notes v1.0.x</a></li>
# </ul>
# </li>
# <li class="dropdown-header">CONFIGURATION</li>
# <li class="dropdown-submenu">
# <a href="#" tabindex="-1">Feature Overview</a>
# <ul class="dropdown-menu">
# <li><a href="/features/filedrops.html">Filedrops</a></li>
# <li><a href="/features/emaildrops.html">Emaildrops</a></li>
# <li><a href="/features/ftpdrops.html">FTPdrops &amp; FTPdirs</a></li>
# </ul>
# </li>
# <li class="dropdown-submenu">
# <a href="#" tabindex="-1">General info</a>
# <ul class="dropdown-menu">
# <li><a href="/general/support.html">About LiquidFiles Support</a></li>
# <li><a href="/general/user_classes.html">Local vs External Users</a></li>
# <li><a href="/general/security.html">Security Information</a></li>
# <li><a href="/general/browser_support.html">Browser Support</a></li>
# <li><a href="/general/file_size_limits.html">File Size Limits</a></li>
# </ul>
# </li>
# <li class="dropdown-submenu">
# <a href="#" tabindex="-1">Filedrops</a>
# <ul class="dropdown-menu">
# <li><a href="/filedrops/system_filedrops.html">System Filedrops</a></li>
# <li><a href="/filedrops/user_filedrops.html">User Filedrops</a></li>
# <li><a href="/filedrops/custom_fields.html">Filedrop Custom Fields</a></li>
# <li><a href="/filedrops/prefill.html">Pre-Fill Filedrop Parameters</a></li>
# </ul>
# </li>
# <li class="dropdown-submenu">
# <a href="#" tabindex="-1">Configuration</a>
# <ul class="dropdown-menu">
# <li><a href="/configuration/automatic_group_assignment.html">Automatically Assign<br/>Users to Groups</a></li>
# <li><a href="/configuration/groups.html">Working with Groups</a></li>
# <li><a href="/configuration/ldap.html">LDAP Configuration</a></li>
# </ul>
# </li>
# <li class="dropdown-submenu">
# <a href="#" tabindex="-1">Branding</a>
# <ul class="dropdown-menu">
# <li><a href="/branding/home_page.html">Branding the Home Page</a></li>
# <li><a href="/branding/header.html">Customizing the Header</a></li>
# <li><a href="/branding/footer.html">Customizing the Footer</a></li>
# <li><a href="/branding/favicon.html">Favicon</a></li>
# <li><a href="/branding/custom_stylesheet_user_group.html">Custom stylesheet per<br/>user/group</a></li>
# <li><a href="/branding/error_pages.html">Customizing the init<br/>and error pages</a></li>
# <li><a href="/branding/changing_the_help_page.html">Changing the help page</a></li>
# <li><a href="/branding/displaying_different_content_based_on_locale.html">Displaying different content<br/>based on locale</a></li>
# <li><a href="/branding/stylesheet_and_javascript_overrides.html">Stylesheet and Javascript<br/>overrides</a></li>
# <li><a href="/branding/changing_text_on_page_or_email.html">Changing any text on any<br/>visible page or email</a></li>
# <li><a href="/branding/examples.html">Examples</a></li>
# </ul>
# </li>
# <li class="dropdown-header">SECURITY,<br/>AUTHENTICATION &amp;<br/>AUTHORIZATION</li>
# <li class="dropdown-submenu">
# <a href="#" tabindex="-1">Security</a>
# <ul class="dropdown-menu">
# <li><a href="/general/security.html">General Security Information</a></li>
# <li><a href="/security/av_scanning.html">Antivirus Scanning</a></li>
# <li><a href="/actionscripts/attachment_upload.html">Custom file scanning using Actionscript</a></li>
# <li><a href="/security/web_server_redirect_configuration.html">Web server redirect<br/>configuration</a></li>
# <li><a href="/security/hsts.html">Understanding HSTS</a></li>
# <li><a href="/security/frequent_responses_after_security_reviews.html">Frequent Responses after<br/>security reviews</a></li>
# <li><a href="/security/system_vulnerabilities.html">System Vulnerabilities</a></li>
# <li><a href="/security/compliance.html">Compliance</a></li>
# </ul>
# </li>
# <li class="dropdown-submenu">
# <a href="#" tabindex="-1">Authentication &amp;<br/>Authorization</a>
# <ul class="dropdown-menu">
# <li><a href="/security/password_policy.html">Password Policy</a></li>
# <li><a href="/actionscripts/password_validation.html">Advanced Custom Password<br/>Validation with Actionscript</a></li>
# <li><a href="/security/two_factor_authentication.html">Two Factor Authentication</a></li>
# <li><a href="/security/sso_with_preshared_key.html">Single Sign-On (SSO)<br/>with pre shared key</a></li>
# <li><a href="/security/sso_using_saml.html">Single Sign-On using SAML</a></li>
# <li><a href="/security/sso_saml2_W2008_server.html">SSO SAML2.0 on W2008 R2<br/>server and LiquidFiles</a></li>
# <li><a href="/security/sso_saml2_W2012_server.html">SSO SAML2.0 on W2012 R2<br/>server and LiquidFiles</a></li>
# <li><a href="/security/sso_saml2_azure.html">SSO SAML2.0 in Azure<br/>server and LiquidFiles</a></li>
# <li><a href="/security/download_auth.html">Download Authentication</a></li>
# <li><a href="/security/download_permission.html">Download access<br/>permission (authorization)</a></li>
# </ul>
# </li>
# <li class="dropdown-header">API</li>
# <li class="dropdown-submenu">
# <a href="#" tabindex="-1">General API</a>
# <ul class="dropdown-menu">
# <li class="nav-header">Basics</li>
# <li><a href="/api/introduction_and_authentication.html">Introduction and Authentication</a></li>
# <li><a href="/api/history_and_versions.html">History and Versions</a></li>
# <li><a href="/api/retrieve_api_key.html">Retrieve API key</a></li>
# <li><a href="/api/retrieve_any_users_api_key.html">Retrieve any users API key</a></li>
# <li><a href="/api/client_info_request.html">Client Info Request</a></li>
# <li class="nav-header">Attachments</li>
# <li><a href="/api/attachment_upload.html">Attachment (File Upload) API</a></li>
# <li><a href="/api/attachment_chunks.html">Attachment Chunks</a></li>
# <li><a href="/api/delete_attachments.html">Delete Attachments</a></li>
# <li class="nav-header">Messages</li>
# <li><a href="/api/secure_messages.html">Secure Messages</a></li>
# <li><a href="/api/list_sent_messages.html">List Sent Messages</a></li>
# <li><a href="/api/validate_recipients_api.html">Validate Recipients API</a></li>
# <li><a href="/api/list_messages_and_download_attachments.html">List Messages and<br/>Download Attachments</a></li>
# <li class="nav-header">Filedrop</li>
# <li><a href="/api/filedrop.html">Filedrop API</a></li>
# <li class="nav-header">File Requests</li>
# <li><a href="/api/file_request_api.html">File Request API</a></li>
# <li class="nav-header">FileLink</li>
# <li><a href="/api/filelink_api.html">FileLink API</a></li>
# <li class="nav-header">Download</li>
# <li><a href="/api/download.html">Download Log API</a></li>
# <li class="nav-header">Other</li>
# <li><a href="/api/development.html">Development (C#, .NET, Java, ...)</a></li>
# <li><a href="/api/v2/">LiquidFiles v2.x XML API</a></li>
# <li><a href="/api/shares/list_shares.html"><b>Share:</b> List</a></li>
# <li><a href="/api/shares/view_share.html"><b>Share:</b> View</a></li>
# <li><a href="/api/shares/view_folder.html"><b>Folder:</b> View</a></li>
# <li><a href="/api/shares/create_folder.html"><b>Folder:</b> Create</a></li>
# <li><a href="/api/shares/delete_folder.html"><b>Folder:</b> Delete</a></li>
# <li><a href="/api/shares/rename_folder.html"><b>Folder:</b> Rename</a></li>
# <li><a href="/api/shares/move_folder.html"><b>Folder:</b> Move</a></li>
# <li><a href="/api/shares/view_file.html"><b>File:</b> View</a></li>
# <li><a href="/api/shares/download_file.html"><b>File:</b> Download</a></li>
# <li><a href="/api/shares/upload_file.html"><b>File:</b> Upload</a></li>
# <li><a href="/api/shares/delete_file.html"><b>File:</b> Delete</a></li>
# <li><a href="/api/shares/rename_file.html"><b>File:</b> Rename</a></li>
# <li><a href="/api/shares/move_file.html"><b>File:</b> Move</a></li>
# <li><a href="/api/shares/restore.html"><b>File/Folder:</b> Restore</a></li>
# </ul>
# </li>
# <li class="dropdown-submenu">
# <a href="#" tabindex="-1">Admin API</a>
# <ul class="dropdown-menu">
# <li><a href="/admin_api/introduction_to_the_admin_api.html">Introduction to the Admin API</a></li>
# <li><a href="/admin_api/user_admin_api.html">User Admin API</a></li>
# <li><a href="/admin_api/group_admin_api.html">Group Admin API</a></li>
# <li><a href="/admin_api/filedrop_admin_api.html">Filedrop Admin API</a></li>
# <li><a href="/admin_api/pool_admin_api.html">Pool Admin API</a></li>
# <li><a href="/admin_api/shares/create_share.html">Create Share API</a></li>
# <li><a href="/admin_api/shares/list_shares.html">List/View Shares API</a></li>
# <li><a href="/admin_api/shares/delete_share.html">Delete Shares API</a></li>
# <li><a href="/admin_api/shares/add_access.html">Add/Update Share Access API</a></li>
# <li><a href="/admin_api/shares/remove_access.html">Remove Share Access API</a></li>
# </ul>
# </li>
# <li class="dropdown-header">SYSTEM</li>
# <li class="dropdown-submenu">
# <a href="#" tabindex="-1">General System</a>
# <ul class="dropdown-menu">
# <li><a href="/system/firewall.html">Network &amp; Firewall<br/>configuration</a></li>
# <li><a href="/system/dns.html">DNS</a></li>
# <li><a href="/system/http_redirect_configuration.html">HTTP/HTTPS redirect<br/>configuration</a></li>
# <li><a href="/system/reverse_proxy.html">Reverse Proxy Configuration</a></li>
# <li><a href="/system/console.html">Logging in to the<br/>System Console</a></li>
# </ul>
# </li>
# <li class="dropdown-submenu">
# <a href="#" tabindex="-1">Certificates</a>
# <ul class="dropdown-menu">
# <li><a href="/certificates/">Overview</a></li>
# <li><a href="/certificates/install.html">Certificate Install Guide</a></li>
# <li><a href="/certificates/lets_encrypt.html">Let's Encrypt</a></li>
# <li><a href="/certificates/csr.html">Generate CSR</a></li>
# <li><a href="/certificates/custom_csr.html">Generate Custom CSR</a></li>
# <li><a href="/certificates/wildcard.html">Wildcard Certificates</a></li>
# <li><a href="/certificates/troubleshooting.html">Troubleshooting</a></li>
# <li><a href="/certificates/backup.html">Backup &amp; Restore Certificates</a></li>
# <li><a href="/certificates/convert.html">Convert SSL formats</a></li>
# <li><a href="/certificates/general.html">General Information</a></li>
# </ul>
# </li>
# <li class="dropdown-submenu">
# <a href="#" tabindex="-1">Disk and Storage</a>
# <ul class="dropdown-menu">
# <li><a href="/disk_and_storage/using_an_external_nfs_server.html">Using an external NFS server</a></li>
# <li><a href="/disk_and_storage/expanding_disk_size.html">Expanding disk size</a></li>
# <li><a href="/disk_and_storage/encrypted_filesystem.html">Encrypted Filesystem</a></li>
# <li><a href="/disk_and_storage/increasing_disk_size_in_ec2.html">Increasing Disk Size in EC2</a></li>
# </ul>
# </li>
# <li class="dropdown-submenu">
# <a href="#" tabindex="-1">Email</a>
# <ul class="dropdown-menu">
# <li><a href="/system/delivering_emails.html">Delivering Emails</a></li>
# <li><a href="/system/outgoing_smtp_elasticemail.html">Outgoing SMTP Relay<br/>with ElasticEmail</a></li>
# <li><a href="/system/outgoing_smtp_exchange.html">Outgoing SMTP Relay<br/>with Microsoft Exchange</a></li>
# <li><a href="/system/outgoing_smtp_office365.html">Outgoing SMTP Relay<br/>with Office 365</a></li>
# <li><a href="/troubleshoot/email.html">Troubleshooting Email Delivery</a></li>
# </ul>
# </li>
# <li class="dropdown-submenu">
# <a href="#" tabindex="-1">Troubleshooting</a>
# <ul class="dropdown-menu">
# <li><a href="/troubleshoot/network.html">Troubleshooting Network<br/>Connections</a></li>
# <li><a href="/troubleshoot/email.html">Troubleshooting Email Delivery</a></li>
# <li><a href="/troubleshoot/status_checks.html">How does the Status Checks work?</a></li>
# <li><a href="/troubleshoot/network_performance.html">Testing Network Performance</a></li>
# </ul>
# </li>
# </ul>
# </li>
# </div>
# </div>
# </nav>
# </header>
# <div class="container hidden-md hidden-lg" id="toppage_search" style="margin-top: 70px;">
# <div class="row">
# <div class="col-xs-12">
# <form action="/search.html" class="form" method="get" role="search">
# <div class="input-group input-group-lg">
# <input class="form-control input-lg" id="toppage_search_field" name="q" placeholder="Search" type="text"/>
# <span class="input-group-btn">
# <button class="btn btn-primary btn-lg" type="submit"><i class="fa fa-search"></i> Search</button>
# </span>
# </div>
# </form>
# </div>
# </div>
# </div>
# <hr id="header-line"/>
# <div class="visible-print-block">
# <div class="pull-right">https://man.liquidfiles.com</div>
# <img alt="LiquidFiles Documentation" height="25" src="/assets/images/header_logo-338e20fa3f38c137f204e241769f9d2e8640c7e4e779acadb5d453fb96267cf1.png" width="312"/>
# </div>
# <div class="container" id="content">
# <div class="row">
# <div class="col-md-3 scrollspy">
# <div class="nav-sidebar hidden-xs hidden-sm hidden-print">
# <ul class="nav well" data-spy="affix" id="affix-nav">
# <li class="nav-header"><a href="#secure_messages">Sending Secure Messages</a>
# <ul class="nav nav-pills nav-stacked">
# <li><a href="#sending_files">Compose page</a></li>
# <li><a href="#permissions">Forwarding Permission</a></li>
# <li><a href="#uploading">Uploading the files</a></li>
# <li><a href="#processing">Processing the files</a></li>
# <li><a href="#browser_support">Browser Support</a></li>
# <li><a href="#email">The Recipients Email</a></li>
# <li><a href="#checksum">Checksum</a></li>
# </ul>
# </li>
# <li class="nav-header"><a href="#receive_files">Receive Files</a>
# <ul class="nav nav-pills nav-stacked">
# <li><a href="#file_requests">Request Files</a></li>
# <li><a href="#filedrop">Filedrop</a></li>
# </ul>
# </li>
# <li class="nav-header"><a href="#filelink">FileLink</a>
# <ul class="nav nav-pills nav-stacked">
# <li><a href="#using_filelinks">Using FileLinks</a></li>
# </ul>
# </li>
# <li class="nav-header"><a href="#plugins">Plugins</a>
# <ul class="nav nav-pills nav-stacked">
# <li><a href="#outlook">Outlook plugin</a></li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# <div class="col-md-9" id="bd" style="padding-bottom: 80px;">
# <div class="page-header" id="top">
# <h1>User Guide <small>How to get the most out of LiquidFiles</small></h1>
# </div>
# <p>This is the User Guide for LiquidFiles. It will give basic guidelines how to use LiquidFiles, and also
#       walk through the available settings to make sure you get the most from using it.</p>
# <hr id="sending_files"/>
# <h2>Sending Files <small>Using the standard compose window</small></h2>
# <p>This is how the main compose window looks in LiquidFiles:</p>
# <img alt="images/userguide/compose_1.png" class="img-responsive" height="818" src="/assets/images/userguide/compose_1-f1a287ff456fe9f88b550d540ec9a3edfb2c7daee281c9b138a6631cc9b7d710.png" width="1059"/>
# <p>When sending files, these are the steps and options available:</p>
# <ol>
# <li>Select recipients in the same way as a web based email system, please select To, CC and BCC email
#     addresses to your recipients.</li>
# <li>Type the Subject and Message to your recipients.</li>
# <li>Add Files, you can add files up to the max size displayed in the limitations section 10).</li>
# <li>When you're ready, please hit Send. If uploads are taking a long time, you can check the checkbox to
#     "send when uploads are done".</li>
# <li>If you have sent any files previously, you can send them again without uploading them again.</li>
# <li>Pool files are files that an administrator can make available for groups of users that they send repeatadly,
#     like a large companywide presentation and similar.</li>
# <li>Select Download Permission for your recipients. See the <a href="#permissions">Forwarding Permissions</a>
#     section for a complete description.</li>
# <li>When the message expires. After this day, the attached files will be deleted.</li>
# <li>If set, each recipient can only download each file this number of times. If the download
#     permission is set to "Anyone", each download by anyone is counted towards the limit.
#   </li>
# <li>Send a copy to your own email address (for storage in your sent folder).</li>
# <li>A Private Message is a message where the Message is not included in the email sent to the recipients. When
#     sending a Private Message:
#     <ul>
# <li>The recipients will get a generic email telling them to click on the link to view the message.</li>
# <li>You will get a read receipt when the recipient has viewed the message as well as when any
#       attachments has been downloaded.</li>
# <li>You can send a Private Message without any attachments.</li>
# <li>It's not possible to send a Private Message with the permission that Anyone can download —
#       in order to send a Private Message, authentication is required.</li>
# </ul>
# </li>
# <li>Limitations — Message Size, Quota and File Extension Limitations.</li>
# </ol>
# <a class="hidden-print" href="#top">Back to top</a>
# <hr id="permissions"/>
# <h3>Forwarding Permissions</h3>
# <table class="table">
# <thead>
# <tr>
# <th>Permission</th>
# <th class="center">Require Authentication</th>
# <th>Download Receipt</th>
# <th>Description</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>Only Specified Recipients</td>
# <td class="center">Yes</td>
# <td>When each recipient download each file.</td>
# <td>Only the recipients you have specified in the
#         To, CC and BCC fields will be able to download the files. It won't be possible to forward the email or
#         message URL to anyone.
#       </td>
# </tr>
# <tr>
# <td>Only Specified Recipients and Local users</td>
# <td class="center">Yes</td>
# <td>When each recipient download each file.</td>
# <td>In addition to the Specified Recipients,
#         any files sent may also be downloaded by any local users on the system by forwarding the email
#         or sending the message URL.</td>
# </tr>
# <tr>
# <td>Only Specified Recipients and Respective Domain Users can access</td>
# <td class="center">Yes</td>
# <td>When each recipient download each file.</td>
# <td>In addition to the Specified Recipients,
# 	  any files sent may also be downloaded by any user with same email domain as the email domain
# 	  of the first recipient by forwarding the email or sending the message URL.</td>
# </tr>
# <tr>
# <td>Anyone after authentication</td>
# <td class="center">Yes</td>
# <td>When each recipient download each file.</td>
# <td>Anyone may download the files. Use this option to
#         post the Public Message URL in public forums, on web pages or anywhere where you want to make the files available.
#         When the user visits the Public URL, they will be asked to authenticate by providing their email address
#         and a confirmation.</td>
# </tr>
# <tr>
# <td>Anyone</td>
# <td class="center">No</td>
# <td>Once per file, when someone has downloaded the file.</td>
# <td>Anyone may download the files. Use this option when you don't want your recipients to have to
#         authenticate to download the files. The downside is that since we don't authenticate the recipients,
#         we don't know who downloaded what.</td>
# </tr>
# </tbody>
# </table>
# <a class="hidden-print" href="#top">Back to top</a>
# <hr id="uploading"/>
# <h3>Uploading the Files</h3>
# <p>There are two methods for uploading files — HTML 5 and Legacy. The most commonly used browsers support the HTML 5 upload mechanism
#   except Internet Explorer until version 10. Please see the
#   <a href="#browser_support">Browser Support</a> section for a complete list of supported browsers.</p>
# <p>When uploading using a HTML 5 compliant browser, files are uploaded as you compose the message and looks like this:</p>
# <img alt="images/userguide/uploading_1.png" class="img-responsive" height="238" src="/assets/images/userguide/uploading_1-afeda250a41167b7b2f5a47c8b4a2116bfc6dc0b3d8a16acd3e3f4702ca12037.png" width="809"/>
# <p>When uploading using a Legacy browser (Internet Explorer 9 and below, and really old
#   (and <a hred="#browser_support">unsupported</a>) versions of Firefox, Chrome &amp; Safari),
#   files are <strong>not uploaded when you select them</strong>. Instead, the bottom of the compose page will look like this:</p>
# <img alt="images/userguide/uploading_2.png" class="img-responsive" height="271" src="/assets/images/userguide/uploading_2-47ae3f7908f78944cebb87661e0d20ccaa98e0a382f273d7bec1ad550604c847.png" width="807"/>
# <p>In this case, you will see the browser limitation in the Limitations section, and you will see the files selected at the
#   bottom of the page. When you hit send, you will see an upload window like this:</p>
# <img alt="images/userguide/uploading_3.png" class="img-responsive" height="256" src="/assets/images/userguide/uploading_3-e82a696c166ce9d3e9150cd269e2ea4fe06c4c691108282dc3de9cb7e1cd2ced.png" width="648"/>
# <p>Please note that LiquidFiles checks for the presence of the required HTML 5 File.API. There is no check for specific
# browser versions when it comes to selecting HTML 5 vs Legacy upload mechanisms. If Microsoft decides to add support for
# the HTML 5 File.API in Internet Explorer 9 (very unlikely), it will automatically be picked up and used in LiquidFiles.</p>
# <a class="hidden-print" href="#top">Back to top</a>
# <hr id="processing"/>
# <h3>Processing Uploaded Files</h3>
# <p>When large files are sent (with the HTML 5 method), they are split into 100 Mb blocks. All files are also scanned for viruses.
#   This can take some time on a busy system and the files are
#   placed in a queue for reassembly and AV scan. As per the notice beneath the files, you don't have to wait for this to
#   complete to send the message. In the unlikely event of an infected file, the file will be automatically deleted before anyone
#   can download the file.</p>
# <img alt="images/userguide/processing.png" class="img-responsive" height="235" src="/assets/images/userguide/processing-ac00d5de94458a830fd6d75bedd05fcb709c12f54de7b954de2d0ffab5522af1.png" width="828"/>
# <a class="hidden-print" href="#top">Back to top</a>
# <hr id="browser_support"/>
# <h3>Browser Support</h3>
# <p>LiquidFiles pushes some boundaries of what’s possible with browsers.
#   In general, <strong>the two most recent major releases of the four most popular browsers are supported</strong>,
#   except with Internet Explorer where the three most recent major releases are supported.</p>
# <p>Please see the matrix below for different browser versions and their limitations:</p>
# <table class="table table-condensed table-striped">
# <thead>
# <tr>
# <th>Browser</th>
# <th class="center">Upload Mechanism</th>
# <th class="center">Max Download</th>
# <th class="center">Max Upload</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>Microsoft Edge</td>
# <td class="center">HTML 5</td>
# <td class="center">No Limit</td>
# <td class="center">No Limit</td>
# </tr>
# <tr>
# <td>Internet Explorer 11</td>
# <td class="center">HTML 5</td>
# <td class="center">No Limit</td>
# <td class="center">No Limit</td>
# </tr>
# <tr>
# <td>Internet Explorer 10</td>
# <td class="center">HTML 5</td>
# <td class="center">No Limit</td>
# <td class="center">No Limit</td>
# </tr>
# <tr>
# <td>Internet Explorer 9</td>
# <td class="center">Legacy</td>
# <td class="center">No Limit</td>
# <td class="center">4 Gb</td>
# </tr>
# <tr>
# <td>Internet Explorer 8</td>
# <td class="center">Legacy</td>
# <td class="center">No Limit</td>
# <td class="center">2 Gb</td>
# </tr>
# <tr>
# <td><abbr title="Since Chrome is self updating, it is assumed that you're running the latest version.">Chrome</abbr></td>
# <td class="center">HTML 5</td>
# <td class="center">No Limit</td>
# <td class="center">No Limit</td>
# </tr>
# <tr>
# <td><abbr title="Since Firefox is self updating, it is assumed that you're running the latest version.">Firefox</abbr></td>
# <td class="center">HTML 5</td>
# <td class="center">No Limit</td>
# <td class="center">No Limit</td>
# </tr>
# <tr>
# <td>Safari</td>
# <td class="center">HTML 5</td>
# <td class="center">No Limit</td>
# <td class="center">No Limit</td>
# </tr>
# </tbody>
# </table>
# <p>LiquidFiles will automatically detect the presence of the HTML 5 File.API needed to send files with unlimited
#   file size. While there is some support for HTML5 in IE9, it doesn't support the File.API. Internet Explorer 10
#   is the first version of Internet Explorer to support the HTML 5 File.API.</p>
# <p>The Send limitations are limitations in each browser. It’s not possible to "fix" Internet Explorer 8 or 9 to
#   send a 8Gb file, these are the inherit limits of those browsers.</p>
# <p>The Browser file size limitation problem is compounded with a sort of - how do we describe 30 hours on a 12 hour clock? 2 revolutions and
#   6 o'clock. But since the equivalent of revolutions doesn't exists, all we're left with is 6 o'clock, or back
#   in computer land - a 5 Gb file uploaded in IE9 will be uploaded as a 1Gb file. It just "turns over" every 4Gb.
#   The following message is shown if someone has a setting that would allow them to upload a larger file, but
#   their browser prevents them:</p>
# <img alt="images/userguide/uploading_2.png" class="img-responsive" height="271" src="/assets/images/userguide/uploading_2-47ae3f7908f78944cebb87661e0d20ccaa98e0a382f273d7bec1ad550604c847.png" width="807"/>
# <p>Since we cannot detect properly in this case if someone have selected a larger than 4Gb file, this is so far
#   the best we can do, and probably the way it's going to stay until IE 11 or 12 when we can (finally) end
#   support for the non HTML5 compliant versions of Internet Explorer.</p>
# <a class="hidden-print" href="#top">Back to top</a>
# <hr id="email"/>
# <h2>The Recipients Email</h2>
# <p>When you have clicked Send, an email will be sent to your recipients. Depending on what system they use to
#   read the email it will look a little bit different, and something like this:</p>
# <img alt="images/userguide/email.png" class="img-responsive" height="500" src="/assets/images/userguide/email-a31c80c7ac65ec312b830f8014870dcf9c72f0e284cac333cda16c929f34fdfe.png" width="776"/>
# <p>You will see:</p>
# <ul>
# <li>The email header with the To, From, Subject and so on at the top.</li>
# <li>The message typed in the message field in the compose window.</li>
# <li>The Files attached to the message header that begins the LiquidFiles added part.</li>
# <li>Each file sent is then listed together with the filename, file size and <a href="#checksum">checksum</a>.</li>
# <li>Beneath the files is the link the recipient will have to click to download the message.</li>
# <li>There is a notice if the email or download link can be forwarded to other users depending on the
#     <a href="#permissions">permission settings</a> when the message was sent.</li>
# <li>There's an expiration notice alerting the user when they will have to download the files by.</li>
# <li>And finally there's a Message ID which is a unique ID that can be used when searching for this message in the LiquidFiles system.</li>
# </ul>
# <p>A couple of things to note:</p>
# <ul>
# <li>There's obviously no files attached directly in this email. All the files are store on the LiquidFiles system.</li>
# <li>When the message expires, the attachments will be automatically deleted. It's not possible to restore files
#     that have been deleted.</li>
# </ul>
# <a class="hidden-print" href="#top">Back to top</a>
# <hr id="checksum"/>
# <h2>Checksum <small>or how to verify the integrity of the downloaded files</small></h2>
# <p>A <a href="http://en.wikipedia.org/wiki/Checksum" target="_blank">checksum</a>,
#   or <a href="http://en.wikipedia.org/wiki/Cryptographic_hash_function" target="_blank">hash</a> is a way
#   to verify the integrity of the downloaded files, to verify that the download was successful.</p>
# <p>It works by applying a cryptographic calculation on a file of any size and it will output a short
#   checksum, or hash, that represents the message or file.</p>
# <p>The trick with checksums or hashes is that every time they calculate the checksum for the same file, they will produce
#   the same checksum. And if the file changes only one single bit, the calculation will produce a different checksum.</p>
# <p>So when you receive a message from the LiquidFiles system, and it displays a checksum like:
#   <tt>36f037e00350864828a507420a50689eb473cb919df6b4b6205f3e09c913e0cb</tt> you can use a
#   <a href="http://en.wikipedia.org/wiki/Checksum#Checksum_tools" target="_blank">Checksum Tool</a>
#   to calculate the checksum of the file you downloaded. LiquidFiles uses SHA-256 as its checksum function
#   (sometimes referred to as SHA2-256).</p>
# <p>If the checksum is the same, the file you have downloaded is identical to the one sent from the LiquidFiles system.</p>
# <p>If the checksum is not the same, the file you downloaded is not the same as the one sent from the LiquidFiles system.</p>
# <p>So as an example, lets say that we received a message with the following attachment:</p>
# <img alt="images/userguide/checksum_1.png" class="img-responsive" height="94" src="/assets/images/userguide/checksum_1-588c90920ecdff46ceb8320ac94794a7add431c487a640f68290f8e5d5923157.png" width="753"/>
# <p>We use a Windows applications from the list of
# <a href="http://en.wikipedia.org/wiki/Checksum#Checksum_tools" target="_blank">Checksum Tools</a> at Wikipedia to calculate the
# checksum of the file we downloaded, selecting SHA2-256 as the checksum function (or hash type).</p>
# <img alt="images/userguide/checksum_2.png" class="img-responsive" height="278" src="/assets/images/userguide/checksum_2-84e62b6edde5118677079503edf65fcc521408aca592bf6e0079fbe82e8a6f8f.png" width="719"/>
# <p>As you can see, the checksum in the message is the same as from the downloaded file. The file must be identical to the
#   one on the LiquidFiles system.</p>
# <a class="hidden-print" href="#top">Back to top</a>
# <div class="page-header" id="receive_files">
# <h1>Receive Files</h1>
# </div>
# <hr id="file_requests"/>
# <h2>Request Files <small>an easy way to receive files with no prior registration required</small></h2>
# <p>File Requests provides an easy way for you to request files from someone. The system will make it very easy so that
#   there's no need to do any further explanation, or walk someone through the process over the phone.</p>
# <p>You Request the Files by clicking on the
#   File Request button in the main compose page.</p>
# <img alt="images/userguide/file_request_1.png" class="img-responsive" height="236" src="/assets/images/userguide/file_request_1-371e6383809f54a631e7e6a74cf2216c8b438931dcd063c010da1668ec4a3985.png" width="616"/>
# <p>This will open up a popup window that you can fill in like this:</p>
# <img alt="images/userguide/file_request_2.png" class="img-responsive" height="521" src="/assets/images/userguide/file_request_2-2639a7e0cb8202050e1b994835a503c561ee4e5eb2fd30f6314b0d6746e5da66.png" width="911"/>
# <p>When you click on the Request File button, an email will be delivered (to <tt>meg@external.com</tt> in our example)
#   with a unique File Request link. The email will look something like this:</p>
# <img alt="images/userguide/file_request_3.png" class="img-responsive" height="409" src="/assets/images/userguide/file_request_3-64dbd8d713f4b24413bce58fdaeb3c7fccd20462801a1a6797b23e99c85b6951.png" width="652"/>
# <p>And when the user clicks on the File Request, they will be taken to a page that will look something like this:</p>
# <img alt="images/userguide/file_request_4.png" class="img-responsive" height="655" src="/assets/images/userguide/file_request_4-61f4bb3807ba817d90f88da0dc23b00f1f923988551d2e236d7ed52feec92125.png" width="832"/>
# <p>Where they can send the Requested Files back to the requester.</p>
# <p>A couple of things to note:</p>
# <ul>
# <li>The Link is one time use only and will expire when the files have been delivered. If you need something to be used more than once, please look at using the <a href="#filedrop">Filedrop</a> instead.</li>
# <li>The user that got the link doesn't need to register or do anything other than clicking on the link in the email, and
#     since they got the email with the link, we know that the email address is valid.</li>
# </ul>
# <a class="hidden-print" href="#top">Back to top</a>
# <hr id="filedrop"/>
# <h2>Filedrop <small>an easy way to receive files with no prior registration required</small></h2>
# <p>A Filedrop is a permanent URL that you can use to receive files. You can for instance:</p>
# <ul>
# <li>Add this link to your email signature.</li>
# <li>Post in forums and other public places where you also would be comfortable to post your email address.</li>
# <li>Send to anyone in a private email for them to use when sending files to you repeatedly.</li>
# </ul>
# <p>You can get your Filedrop link by going to the Account Section. It will look something like this:</p>
# <img alt="images/userguide/filedrop_1.png" class="img-responsive" height="188" src="/assets/images/userguide/filedrop_1-c15e509426b64184a41b4d295ba4904667cbdba0c92f9261b039092c678355bc.png" width="1104"/>
# <p>You will see two links, one random and one with your email address.</p>
# <img alt="images/userguide/filedrop_2.png" class="img-responsive" height="392" src="/assets/images/userguide/filedrop_2-28118967f671ace5ffa46f4e385e3bf16bef9b8444d22a7bd425d78a572dc4b0.png" width="1103"/>
# <p>The random link is a link which can't be guessed so it is safer to post in places when you're not sure
#   if you want to share your email address. If the link ever falls in the wrong hands, you can always
#   go back to this page and click on the "Reset Filedrop URL" button. This will generate a new random
#   Filedrop URL for you. Please note that this will automatically expire your previous URL so anyone
#   who will try to use the previous URL will get a 404 page not found message.</p>
# <p>The link with your email looks nicer and is easier to validate if someone has to type it in. But this
#   link will never expire (unless you change email address).</p>
# <p>When someone visits your Filedrop URL (https://liquidfiles.company.com/filedrop/~VZ209z in this example), they will see a page like this:</p>
# <img alt="images/userguide/filedrop_3.png" class="img-responsive" height="763" src="/assets/images/userguide/filedrop_3-724f50e04d99179f908d70cd10704dc95c12efdefed0e32272eecb8802f99f74.png" width="858"/>
# <p>Anyone who visits this page will be able to send files to you by filling in all the fields, clicking on the
#   "Add Files" button and clicking "Send". Please note that there is no "To" field. Since this is <strong>your
#     Filedrop URL</strong>, all files sent here will always be delivered to you.</p>
# <a class="hidden-print" href="#top">Back to top</a>
# <!-- ######################## FileLink ######################## -->
# <div class="page-header" id="filelink">
# <h1>FileLinks</h1>
# </div>
# <h2 id="using_filelinks">Using FileLinks <small>an easy way to send links to individual file</small></h2>
# <p>FileLinks are direct links to files. The primary use case is to be able to send links to files when
#   you don't necessarily know the recipient before hand, or just want something quick and easy. It's also great
#   for posting links in oline forums, in instant messaging apps and so on.</p>
# <p>The FileLink interface can be reached by selecting FileLink in the menubar.</p>
# <img alt="images/userguide/filelink_1.png" class="img-responsive" height="180" src="/assets/images/userguide/filelink_1-2eaa16854baac1b8f3dedad6d818274444ad2f057105c0a5f456491c4eadbc1c.png" width="813"/>
# <p>The main FileLink interface looks like this, with the following options.</p>
# <img alt="images/userguide/filelink_2.png" class="img-responsive" height="316" src="/assets/images/userguide/filelink_2-f122a0f84303b0d48b82e3a9fcbcd6a2b77f2a0705c60cbde8c7cfad4afae34c.png" width="1066"/>
# <ol>
# <li>The Tab to create new FileLinks.</li>
# <li>The Tab to list existing FileLinks.</li>
# <li>The Tab to list available files, so that you can create FileLinks without uploading new files.</li>
# <li>Selecting a new file to create the FileLink.</li>
# <li>Creating the FileLink after the file has been selected.</li>
# <li>Limitations on file size and file type will be listed here.</li>
# </ol>
# <h4 style="margin-top: 40px;">Creating a FileLink</h4>
# <p>When selecting a file, you will have the following options.</p>
# <img alt="images/userguide/filelink_3.png" class="img-responsive" height="322" src="/assets/images/userguide/filelink_3-36911f3a9452ea7baa37cc1e19e59ea9c920dd319d04e7877a94ccbe661d8706.png" width="701"/>
# <ol>
# <li>The selected file, with file size and remove button.</li>
# <li>When the FileLink expires. After this date, anyone visiting the FileLink won't be able to access it.</li>
# <li>When enabled, you will receive a confirmation email after each download of the FileLink.</li>
# <li>When enabled, each user will be required to authenticate before accessing the FileLink. If the user
#     doesn't have an account on the LiquidFiles system, they will authenticate with their email address.</li>
# <li>When you're ready, Create Link to create the FileLink.</li>
# </ol>
# <h4 style="margin-top: 40px;">The FileLink Page</h4>
# <p>When a user is visiting the FileLink, they will see the following page.</p>
# <img alt="images/userguide/filelink_4.png" class="img-responsive" height="464" src="/assets/images/userguide/filelink_4-a93a58a0c24dc687275726daa8022f1ce6364fca96e577e77ff82d8e47b931e7.png" width="811"/>
# <ol>
# <li>The file details including filename, file size and SHA-256 checksum.</li>
# <li>The download button.</li>
# </ol>
# <p style="margin-top: 20px;">When you will visit one of your own FileLink pages, will see the following page.</p>
# <img alt="images/userguide/filelink_5.png" class="img-responsive" height="456" src="/assets/images/userguide/filelink_5-01b0009708275c1b16443f107629ee5f186c9be355df305e1c4fddd201841ea2.png" width="703"/>
# <ol>
# <li>The file details including filename, file size and SHA-256 checksum (same as any other user).</li>
# <li>The download button (same as any other user).</li>
# <li>The FileLink expiration date.</li>
# <li>Clicking the copy FileLink to clipboard button will copy the URL to the FileLink to the clipboard.</li>
# <li>Toggle Download Receipts on and off.</li>
# <li>Toggle Require Authentication on and off.</li>
# </ol>
# <div class="alert alert-info alert-block" style="margin-top: 30px;"><strong>Using the "Copy FileLink to Clipboard" function, you can now copy
#   the FileLink in a chat message, post on a forum, post in SharePoint or anywhere else where you want to make this
#   file available.</strong></div>
# <!-- ######################## Outlook Plugin ######################## -->
# <div class="page-header" id="plugins">
# <h1>Plugins</h1>
# </div>
# <hr id="outlook"/>
# <h2>Using the Outlook Plugin</h2>
# <p>If your administrator has installed and enabled the Outlook plugin, when you're composing a message in Outlook, you will
#   see an additional section, like this:</p>
# <img alt="images/userguide/outlook_1.png" class="img-responsive" height="550" src="/assets/images/userguide/outlook_1-b667ce2ebec93ca33310b359f81db6083443dabe8bb1de66acb214e3478fd99f.png" width="1158"/>
# <p>These are the selectable options in the LiquidFiles Secure Attach Dropdown menu:</p>
# <ol>
# <li>Secure Attach — any file you would normally attach using the attach icon on Outlook can be attached using this
#     Secure Attach button instead. This will cause any file attached to the email to be sent using LiquidFiles.</li>
# <li>Attach Folder — you can also attach a folder at once and all files in this folder will be attached to this email.</li>
# <li>Secure Attach All — the Outlook plugin will automatically send large files through LiquidFiles. If you have
#     a combination of larger and smaller attachments, that means that some will go through LiquidFiles and some direct. By
#     Selecting Secure Attach All, all files, large and small, will be sent through LiquidFiles.</li>
# <li>File Request — use LiquidFiles to request a large and/or sensitive file from someone. The receipient of
#     the File Request will receive a link they can use and any files attached will be delivered safely back to you.</li>
# <li>Private Message — this will cause the body of the email to be sent securely through LiquidFiles with or without
#     any attachments. You will get confirmation when someone has opened your email as well as downloaded any attachments.</li>
# <li>Select Existing Files — this will list already uploaded files from previous messages that you can send again
#     without having to upload.</li>
# <li>Options — configure the LiquidFiles Outlook plugin.</li>
# </ol>
# <h3>Sending a file through LiquidFiles</h3>
# <p>When you have selected a file to attach and send through LiquidFiles, another pane will open up like this:</p>
# <img alt="images/userguide/outlook_2.png" class="img-responsive" height="269" src="/assets/images/userguide/outlook_2-4db37fae6cafaa0be0b4fb161f65fb9d0f0cd862bf631685b1af110ce743344d.png" width="640"/>
# <p>Here you can see the attached file with some basic settings for this message. For more advanced settings, please look in the ribbon:</p>
# <img alt="images/userguide/outlook_3.png" class="img-responsive" height="472" src="/assets/images/userguide/outlook_3-8783014b1d2f284b7be16c26ea7f7455e225c3f2bf282a3fe1c7ecf047a9fe03.png" width="924"/>
# <p>Or as a close-up:</p>
# <img alt="images/userguide/outlook_3b.png" class="img-responsive" height="250" src="/assets/images/userguide/outlook_3b-04ac6c20427b1e192312b46cb7446bbf75922a2df07147cdf447865ee7c01081.png" width="434"/>
# <p>In the top ribbon you can see the LiquidFiles settings for this message, from the top left:</p>
# <ul>
# <li>You can choose to send this message requiring Authentication to access.</li>
# <li>You can choose to send this message as a Private Message (when the body of the email is sent privately through LiquidFiles).</li>
# <li>You can select the <a href="#permissions">Access Permission</a>, same as you would see in the web interface. In the screenshot,
#     "Only Specified Recipients can access".</li>
# <li>How many times each recipient can download each file.</li>
# <li>When the message will expire.</li>
# </ul>
# <h3>Outlook Settings and configuration</h3>
# <p>When you attach your first file to LiquidFiles, you will see the login window:</p>
# <img alt="images/userguide/outlook_4.png" class="img-responsive" height="311" src="/assets/images/userguide/outlook_4-501d13a8128c0d9fb6e7ea89ebdcd60692c314cf4a4784fbd4c6a21ed5decf8b.png" width="507"/>
# <p>This has the LiquidFiles server address, if the plugin should connect with http, https or automatically detect, and
#   your username and password. The username and password is the same username and password as you login to the LiquidFiles
#   web interface.</p>
# <div class="alert alert-info">
#   Please note that you only have to fill this in once and the LiquidFiles Outlook plugin will keep you logged in even if you
#   change your network password.
# </div>
# <p>The Settings Window looks like this:</p>
# <img alt="images/userguide/outlook_5.png" class="img-responsive" height="458" src="/assets/images/userguide/outlook_5-8144de5a5a17481e520428b684776049733e17d75fb50a3fdb2ad3de4702ce32.png" width="650"/>
# <p>And has the following configurable settings, from the top:</p>
# <ul>
# <li>It displays the currently logged in user.</li>
# <li>How many files you can attach at once and how long you want to see the window visible after you've sent the files.</li>
# <li>Where you want the LiquidFiles Attachment information to be placed
#     (please see <a href="#email">the recipient email</a> to see how the attachment information looks).</li>
# <li>Send the message using HTML or plain text, or do not send any message through LiquidFiles.</li>
# <li>The settings to automatically send attachment above a certain size will attach files to LiquidFiles regardless
#     if you have clicked the "normal" attach or the secure attach button if the file is above this size.</li>
# </ul>
# <a class="hidden-print" href="#top">Back to top</a>
# </div>
# </div>
# </div>
# <footer style="margin-top: 60px;">
# <div id="ft">
# <div class="container" id="ft_content">
# <div class="row">
# <div class="col-md-6">
# <div class="row">
# <div class="col-xs-6">
# <h3>Product</h3>
# <ul style="padding-left: 0;">
# <li><a href="https://www.liquidfiles.com/tour/">Tour</a></li>
# <li><a href="https://www.liquidfiles.com/reviews.html">Testimonials</a></li>
# <li><a href="https://www.liquidfiles.com/pricing.html">Pricing</a></li>
# <li><a href="https://www.liquidfiles.com/download.html">Download &amp; Install</a></li>
# </ul>
# </div>
# <div class="col-xs-6">
# <h3>Company</h3>
# <ul style="padding-left: 0;">
# <li><a href="https://www.liquidfiles.com/support.html">Support</a></li>
# <li><a href="https://www.liquidfiles.com/privacy.html">Privacy Policy</a></li>
# <li><a href="https://www.liquidfiles.com/contact.html">Contact &amp; About</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="col-md-6" id="newsletter">
# <h3>Newsletter</h3>
# <p>Learn about new releases, features &amp; other tips.</p>
# <form class="form" id="maillist_form">
# <div class="row">
# <div class="col-xs-8">
# <input class="form-control" id="maillist_email" name="maillist_email" placeholder="Email" type="text"/>
# </div>
# <div class="col-xs-4">
# <button class="btn btn-primary submit" type="submit">Subscribe</button>
# </div>
# </div>
# </form>
# <p><small>We won't spam you and we will not sell your email address to anyone.</small></p>
# </div>
# </div>
# </div>
# </div>
# <div id="ft_company_info">
# <div class="visible-print-block pull-right" style="text-align: right;"><img alt="LiquidFiles Logo" height="25" src="/assets/images/footer_logo-66138ba5c1e2967f459ca8c0728dbca18e6cfca191a3ad8f4ada1a992d510df0.png" width="111"/><br/><br/>https://man.liquidfiles.com/</div>
# <div class="container">
# <a class="pull-right" href="https://www.liquidfiles.com/"><img alt="LiquidFiles Logo" height="25" src="/assets/images/footer_logo-66138ba5c1e2967f459ca8c0728dbca18e6cfca191a3ad8f4ada1a992d510df0.png" width="111"/></a>
# <div class="row">
# <div class="col-md-8 copyright">
#           © 2011 -
#           <script type="text/javascript">
#           var theDate=new Date()
#           document.write(theDate.getFullYear())
#           </script>.
#           <strong>LiquidFiles</strong>. All Rights Reserved.
#         </div>
# </div>
# </div>
# </div>
# </footer>
# </body>>

# %% [markdown]
# ## Übersetzen

# %%
from googletrans import Translator

# %% [markdown]
# ### Syntax:
# `translated = translator.translate('text zum übersetzeb', src='ko', dest='ja')`
# - src – source language (default: auto)
# - dest – destination language (default: en)
# - origin – original text
# - text – translated text
# - pronunciation – pronunciation

# %%
# Translator erzeugen:
translator = Translator()

# %%
text = "    Send the message using HTML or plain text, or do not send any message through LiquidFiles."

# %%
translated = translator.translate(text, dest='de')

# %%
print(translated.text)
# Out:
# Senden Sie die Nachricht mit HTML oder einfachem Text oder senden Sie keine Nachricht über LiquidFiles.

# %%
from time import sleep
trans=""
file = "testfile"
#file = "usergiude"

with open(file, 'r') as f:
    for line in f.readlines():
        #text = line.read()
        transl = translator.translate(line, dest='de')
        sleep(5)
        print(transl.text)
# Out:
# Benutzerhandbuch So holen Sie das Beste aus LiquidFiles heraus
#
# Dies ist das Benutzerhandbuch für LiquidFiles. Es enthält grundlegende Richtlinien für die Verwendung von LiquidFiles und darüber hinaus
# Gehen Sie die verfügbaren Einstellungen durch, um sicherzustellen, dass Sie sie optimal nutzen.
#
# Senden von Dateien Verwenden des Standardfensters zum Erstellen von Dateien
# So sieht das Hauptfenster in LiquidFiles aus:
#
# Beim Senden von Dateien stehen folgende Schritte und Optionen zur Verfügung:
#
# Wählen Sie Empfänger wie ein webbasiertes E-Mail-System aus. Wählen Sie An, CC und BCC-E-Mail aus
# Adressen an Ihre Empfänger.
# Geben Sie den Betreff und die Nachricht an Ihre Empfänger ein.
# Add Files (Dateien hinzufügen), Sie können Dateien bis zu der im Abschnitt Einschränkungen angegebenen maximalen Größe hinzufügen. 10).
# Wenn Sie fertig sind, klicken Sie bitte auf Senden. Wenn das Hochladen sehr lange dauert, können Sie das Kontrollkästchen auf aktivieren
# msgstr "senden, wenn Uploads abgeschlossen sind".
# Wenn Sie zuvor Dateien gesendet haben, können Sie diese erneut senden, ohne sie erneut hochzuladen.
# Pool-Dateien sind Dateien, die ein Administrator für Benutzergruppen bereitstellen kann, die sie wiederholt senden.
# wie eine große unternehmensweite Präsentation und ähnliches.
# Wählen Sie Download-Berechtigung für Ihre Empfänger. Siehe die Weiterleitungsberechtigungen
# Abschnitt für eine vollständige Beschreibung.
# Wenn die Nachricht abläuft. Nach diesem Tag werden die angehängten Dateien gelöscht.
# Wenn festgelegt, kann jeder Empfänger jede Datei nur so oft herunterladen. Ist der Download
# Die Berechtigung ist auf "Jeder" gesetzt. Jeder Download wird auf das Limit angerechnet.
#
# Senden Sie eine Kopie an Ihre eigene E-Mail-Adresse (zur Speicherung in Ihrem gesendeten Ordner).
# Eine private Nachricht ist eine Nachricht, bei der die Nachricht nicht in der an die Empfänger gesendeten E-Mail enthalten ist. Wann
# Senden einer privaten Nachricht:
#
# Die Empfänger erhalten eine allgemeine E-Mail mit der Aufforderung, auf den Link zu klicken, um die Nachricht anzuzeigen.
# Sie erhalten eine Lesebestätigung, wenn der Empfänger die Nachricht gelesen hat und wenn eine solche vorhanden ist
# Anhänge wurden heruntergeladen.
# Sie können eine private Nachricht ohne Anhänge senden.
# Es ist nicht möglich, eine private Nachricht mit der Erlaubnis zu senden, die jeder herunterladen kann -
# Zum Senden einer privaten Nachricht ist eine Authentifizierung erforderlich.
#
#
# Einschränkungen - Einschränkungen für Nachrichtengröße, Kontingent und Dateierweiterung.
#
# Zurück nach oben
#
# Weiterleitungsberechtigungen

# %%
#transl = translator.translate(dddd, dest='de')

# %% [markdown]
# ## Tokenisation of text into sentences
# using  the ntlk toolkit

# %%
#import nltk
text = ""
infile = "t"
with open(infile, 'r') as inf:
    for i in inf.readlines():
        text = text + i

# %%
from nltk.tokenize import sent_tokenize
# make a list of sentences of text
sents = sent_tokenize(text)

# %%
type(sents)
# Out:
# list

# %% [markdown]
# ### Translate each element of list

# %%
for e in sents:
    transl = translator.translate(e, dest='de')
    sleep(3)
    print(transl.text)
# Out:
# Benutzerhandbuch So nutzen Sie LiquidFiles optimal Dies ist das Benutzerhandbuch für LiquidFiles.
# Es enthält grundlegende Richtlinien für die Verwendung von LiquidFiles sowie Informationen zu den verfügbaren Einstellungen, um sicherzustellen, dass Sie sie optimal nutzen.
# Senden von Dateien mit dem Standard-Erstellungsfenster So sieht das Haupt-Erstellungsfenster in LiquidFiles aus: Beim Senden von Dateien stehen folgende Schritte und Optionen zur Verfügung: Wählen Sie Empfänger wie bei einem webbasierten E-Mail-System aus, wählen Sie An, CC und BCC E-Mail-Adressen an Ihre Empfänger.
# Geben Sie den Betreff und die Nachricht an Ihre Empfänger ein.
# Add Files (Dateien hinzufügen), Sie können Dateien bis zu der im Abschnitt Einschränkungen angegebenen maximalen Größe hinzufügen. 10).
# Wenn Sie fertig sind, klicken Sie bitte auf Senden.
# Wenn das Hochladen lange dauert, können Sie das Kontrollkästchen "Senden, wenn das Hochladen abgeschlossen ist" aktivieren.
# Wenn Sie zuvor Dateien gesendet haben, können Sie diese erneut senden, ohne sie erneut hochzuladen.
# Pool-Dateien sind Dateien, die ein Administrator für Benutzergruppen bereitstellen kann, die sie wiederholt senden, z. B. eine große unternehmensweite Präsentation und ähnliches.
# Wählen Sie Download-Berechtigung für Ihre Empfänger.
# Eine vollständige Beschreibung finden Sie im Abschnitt Weiterleitungsberechtigungen.
# Wenn die Nachricht abläuft.
# Nach diesem Tag werden die angehängten Dateien gelöscht.
# Wenn festgelegt, kann jeder Empfänger jede Datei nur so oft herunterladen.
# Wenn die Download-Berechtigung auf "Jeder" gesetzt ist, wird jeder Download von jedem auf das Limit angerechnet.
# Senden Sie eine Kopie an Ihre eigene E-Mail-Adresse (zur Speicherung in Ihrem gesendeten Ordner).
# Eine private Nachricht ist eine Nachricht, bei der die Nachricht nicht in der an die Empfänger gesendeten E-Mail enthalten ist.
# Beim Senden einer privaten Nachricht: Die Empfänger erhalten eine allgemeine E-Mail mit der Aufforderung, auf den Link zu klicken, um die Nachricht anzuzeigen.
# Sie erhalten eine Lesebestätigung, wenn der Empfänger die Nachricht gelesen und Anhänge heruntergeladen hat.
# Sie können eine private Nachricht ohne Anhänge senden.
# Es ist nicht möglich, eine private Nachricht mit der Berechtigung zu senden, die jeder herunterladen kann. Zum Senden einer privaten Nachricht ist eine Authentifizierung erforderlich.
# Einschränkungen - Einschränkungen für Nachrichtengröße, Kontingent und Dateierweiterung.
# Weiterleitungsberechtigungen Berechtigung Authentifizierung erforderlich Downloadbeleg Beschreibung Nur angegebene Empfänger Ja Wenn jeder Empfänger jede Datei herunterlädt.
# Nur die Empfänger, die Sie in den Feldern An, CC und BCC angegeben haben, können die Dateien herunterladen.
# Es ist nicht möglich, die E-Mail- oder Nachrichten-URL an jemanden weiterzuleiten.
# Nur angegebene Empfänger und lokale Benutzer Ja, wenn jeder Empfänger jede Datei herunterlädt.
# Zusätzlich zu den angegebenen Empfängern können alle gesendeten Dateien auch von allen lokalen Benutzern im System heruntergeladen werden, indem die E-Mail weitergeleitet oder die Nachrichten-URL gesendet wird.
# Nur angegebene Empfänger und entsprechende Domänenbenutzer können auf "Ja" zugreifen, wenn jeder Empfänger jede Datei herunterlädt.
# Zusätzlich zu den angegebenen Empfängern können alle gesendeten Dateien von jedem Benutzer mit derselben E-Mail-Domäne wie die E-Mail-Domäne des ersten Empfängers heruntergeladen werden, indem die E-Mail weitergeleitet oder die Nachrichten-URL gesendet wird.
# Jeder nach der Authentifizierung Ja Wenn jeder Empfänger jede Datei herunterlädt.
# Jeder kann die Dateien herunterladen.
# Verwenden Sie diese Option, um die URL der öffentlichen Nachricht in öffentlichen Foren, auf Webseiten oder an einer beliebigen Stelle zu veröffentlichen, an der Sie die Dateien verfügbar machen möchten.
# Wenn der Benutzer die öffentliche URL besucht, wird er aufgefordert, sich mit seiner E-Mail-Adresse und einer Bestätigung zu authentifizieren.
# Jeder Nein Einmal pro Datei, wenn jemand die Datei heruntergeladen hat.
# Jeder kann die Dateien herunterladen.
# Verwenden Sie diese Option, wenn Ihre Empfänger sich nicht authentifizieren müssen, um die Dateien herunterzuladen.
# Der Nachteil ist, dass wir nicht wissen, wer was heruntergeladen hat, da wir die Empfänger nicht authentifizieren.
# Hochladen der Dateien Es gibt zwei Methoden zum Hochladen von Dateien: HTML 5 und Legacy.
# Die am häufigsten verwendeten Browser unterstützen den HTML 5-Upload-Mechanismus mit Ausnahme von Internet Explorer bis Version 10.
# Eine vollständige Liste der unterstützten Browser finden Sie im Abschnitt Browser-Unterstützung.
# Beim Hochladen mit einem HTML 5-kompatiblen Browser werden Dateien beim Verfassen der Nachricht wie folgt hochgeladen: Beim Hochladen mit einem Legacy-Browser (Internet Explorer 9 und niedriger und wirklich alte (und nicht unterstützte) Versionen von Firefox, Chrome & Safari) , Dateien werden nicht hochgeladen, wenn Sie sie auswählen.
# Stattdessen sieht der untere Rand der Erstellungsseite folgendermaßen aus: In diesem Fall wird die Browser-Einschränkung im Abschnitt Einschränkungen angezeigt, und die ausgewählten Dateien werden am unteren Rand der Seite angezeigt.
# Wenn Sie auf "Senden" klicken, wird ein Upload-Fenster wie das folgende angezeigt: Beachten Sie, dass LiquidFiles prüft, ob die erforderliche HTML 5-Datei.API vorhanden ist.
# Es gibt keine Überprüfung für bestimmte Browserversionen, wenn HTML 5 oder ältere Upload-Mechanismen ausgewählt werden.
# Wenn Microsoft beschließt, Unterstützung für die HTML 5-Datei.API in Internet Explorer 9 hinzuzufügen (sehr unwahrscheinlich), wird diese automatisch erfasst und in LiquidFiles verwendet.
# Hochgeladene Dateien verarbeiten Wenn große Dateien gesendet werden (mit der HTML 5-Methode), werden sie in 100-Mb-Blöcke aufgeteilt.
# Alle Dateien werden auch auf Viren überprüft.
# Dies kann auf einem ausgelasteten System einige Zeit in Anspruch nehmen, und die Dateien werden in eine Warteschlange für den Zusammenbau und den AV-Scan gestellt.
# Gemäß dem Hinweis unter den Dateien müssen Sie nicht warten, bis dieser Vorgang abgeschlossen ist, um die Nachricht zu senden.
# Im unwahrscheinlichen Fall einer infizierten Datei wird die Datei automatisch gelöscht, bevor jemand die Datei herunterladen kann.
# Browser-Unterstützung LiquidFiles erweitert die Möglichkeiten von Browsern.
# Im Allgemeinen werden die zwei neuesten Hauptversionen der vier beliebtesten Browser unterstützt, mit Ausnahme von Internet Explorer, in dem die drei neuesten Hauptversionen unterstützt werden.
# In der folgenden Matrix finden Sie Informationen zu den verschiedenen Browserversionen und deren Einschränkungen: Browser-Upload-Mechanismus Maximaler Download Maximaler Upload Microsoft Edge HTML 5 Kein Limit Kein Limit Internet Explorer 11 HTML 5 Kein Limit Kein Limit Internet Explorer 10 HTML 5 Kein Limit Kein Limit Internet Explorer 9 Legacy Keine Begrenzung 4 GB Internet Explorer 8 Legacy Keine Begrenzung 2 GB Chrome HTML 5 Keine Begrenzung Keine Begrenzung Firefox HTML 5 Keine Begrenzung Keine Begrenzung Safari HTML 5 Keine Begrenzung Keine Begrenzung LiquidFiles erkennt automatisch das Vorhandensein der HTML 5-Datei.API, die zum Senden von Dateien erforderlich ist mit unbegrenzter Dateigröße.
# HTML5 wird in IE9 zwar unterstützt, File.API wird jedoch nicht unterstützt.
# Internet Explorer 10 ist die erste Version von Internet Explorer, die die HTML 5-Datei.API unterstützt.
# Die Sendebeschränkungen sind Beschränkungen in jedem Browser.
# Es ist nicht möglich, Internet Explorer 8 oder 9 zu "reparieren", um eine 8-GB-Datei zu senden. Dies sind die Vererbungsgrenzen dieser Browser.
# Das Problem mit der Beschränkung der Browser-Dateigröße wird durch eine Art von - wie beschreiben wir 30 Stunden im 12-Stunden-Format?
# 2 Umdrehungen und 6 Uhr.
# Da es aber kein Äquivalent zu Revolutionen gibt, bleibt uns nichts anderes übrig als 6 Uhr oder zurück im Computerland - eine im IE9 hochgeladene 5-GB-Datei wird als 1-GB-Datei hochgeladen.
# Es "dreht sich nur um" alle 4 GB.
# Die folgende Meldung wird angezeigt, wenn jemand eine Einstellung hat, die es ihm ermöglicht, eine größere Datei hochzuladen, aber sein Browser verhindert dies: Da wir in diesem Fall nicht richtig erkennen können, ob jemand eine Datei mit mehr als 4 GB ausgewählt hat, ist dies bislang die beste Das können wir, und wahrscheinlich wird es so bleiben, bis IE 11 oder 12, wenn wir die Unterstützung für die nicht HTML5-kompatiblen Versionen von Internet Explorer (endlich) beenden können.
# Die Empfänger-E-Mail Wenn Sie auf Senden geklickt haben, wird eine E-Mail an Ihre Empfänger gesendet.
# Je nachdem, auf welchem ​​System die E-Mail gelesen wird, sieht sie etwas anders aus und sieht ungefähr so ​​aus: Sie sehen: Die E-Mail-Kopfzeile mit An, Von, Betreff und so weiter oben.
# Die Nachricht, die in das Nachrichtenfeld im Erstellungsfenster eingegeben wurde.
# Die an den Nachrichtenkopf angehängten Dateien, mit denen der hinzugefügte Teil LiquidFiles beginnt.
# Jede gesendete Datei wird dann zusammen mit dem Dateinamen, der Dateigröße und der Prüfsumme aufgelistet.
# Unter den Dateien befindet sich der Link, auf den der Empfänger klicken muss, um die Nachricht herunterzuladen.
# Es wird eine Benachrichtigung angezeigt, ob die E-Mail oder der Download-Link abhängig von den Berechtigungseinstellungen beim Senden der Nachricht an andere Benutzer weitergeleitet werden kann.
# Es gibt eine Ablaufbenachrichtigung, die den Benutzer benachrichtigt, wenn er die Dateien herunterladen muss.
# Und schließlich gibt es eine Nachrichten-ID, die als eindeutige ID für die Suche nach dieser Nachricht im LiquidFiles-System verwendet werden kann.
# Ein paar Dinge zu beachten: Es gibt offensichtlich keine Dateien direkt in dieser E-Mail angehängt.
# Alle Dateien werden auf dem LiquidFiles-System gespeichert.
# Wenn die Nachricht abläuft, werden die Anhänge automatisch gelöscht.
# Es ist nicht möglich, gelöschte Dateien wiederherzustellen.
# Prüfsumme oder Überprüfung der Integrität der heruntergeladenen Dateien Mit einer Prüfsumme oder einem Hash können Sie die Integrität der heruntergeladenen Dateien überprüfen und sicherstellen, dass der Download erfolgreich war.
# Es funktioniert durch Anwenden einer kryptografischen Berechnung auf eine Datei beliebiger Größe und gibt eine kurze Prüfsumme oder einen Hash aus, der die Nachricht oder Datei darstellt.
# Der Trick bei Prüfsummen oder Hashes besteht darin, dass jedes Mal, wenn sie die Prüfsumme für dieselbe Datei berechnen, dieselbe Prüfsumme erstellt wird.
# Und wenn die Datei nur ein einziges Bit ändert, erzeugt die Berechnung eine andere Prüfsumme.
# Wenn Sie also eine Nachricht vom LiquidFiles-System erhalten und eine Prüfsumme wie die folgende anzeigen: 36f037e00350864828a507420a50689eb473cb919df6b4b6205f3e09c913e0cb Sie können ein Prüfsummen-Tool verwenden, um die Prüfsumme der heruntergeladenen Datei zu berechnen.
# LiquidFiles verwendet SHA-256 als Prüfsummenfunktion (manchmal als SHA2-256 bezeichnet).
# Wenn die Prüfsumme identisch ist, ist die heruntergeladene Datei identisch mit der vom LiquidFiles-System gesendeten.
# Wenn die Prüfsumme nicht identisch ist, stimmt die heruntergeladene Datei nicht mit der vom LiquidFiles-System gesendeten überein.
# Nehmen wir als Beispiel an, wir haben eine Nachricht mit dem folgenden Anhang erhalten: Wir verwenden Windows-Anwendungen aus der Liste der Prüfsummen-Tools bei Wikipedia, um die Prüfsumme der heruntergeladenen Datei zu berechnen, und wählen SHA2-256 als Prüfsummenfunktion (oder Hash-Typ).
# Wie Sie sehen, entspricht die Prüfsumme in der Nachricht der in der heruntergeladenen Datei.
# Die Datei muss mit der Datei auf dem LiquidFiles-System identisch sein.
# Receive Files Request Files - eine einfache Möglichkeit, Dateien ohne vorherige Registrierung zu empfangen File Requests bietet eine einfache Möglichkeit, Dateien von jemandem anzufordern.
# Das System macht es sehr einfach, so dass Sie keine weiteren Erklärungen abgeben oder jemanden über das Telefon durch den Prozess führen müssen.
# Sie fordern die Dateien an, indem Sie auf der Hauptseite zum Verfassen auf die Schaltfläche Dateianforderung klicken.
# Dies öffnet ein Popup-Fenster, das Sie folgendermaßen ausfüllen können: Wenn Sie auf die Schaltfläche "Datei anfordern" klicken, wird eine E-Mail (in unserem Beispiel an meg@external.com) mit einem eindeutigen Dateianforderungslink gesendet.
# Die E-Mail sieht ungefähr so ​​aus: Und wenn der Benutzer auf die Dateianforderung klickt, wird er zu einer Seite weitergeleitet, die ungefähr so ​​aussieht: Wo er die angeforderten Dateien an den Anforderer zurücksenden kann.
# Ein paar Dinge zu beachten: Der Link ist nur eine einmalige Verwendung und läuft ab, wenn die Dateien geliefert wurden.
# Wenn Sie etwas mehrmals verwenden möchten, schauen Sie sich stattdessen den Filedrop an.
# Der Benutzer, der den Link erhalten hat, muss sich nicht registrieren oder etwas anderes tun, als auf den Link in der E-Mail zu klicken. Da er die E-Mail mit dem Link erhalten hat, wissen wir, dass die E-Mail-Adresse gültig ist.
# Filedrop ist eine einfache Möglichkeit, Dateien ohne vorherige Registrierung zu empfangen. Ein Filedrop ist eine permanente URL, über die Sie Dateien empfangen können.
# Sie können zum Beispiel: Diesen Link zu Ihrer E-Mail-Signatur hinzufügen.
# Posten Sie in Foren und an anderen öffentlichen Orten, an denen Sie auch gerne Ihre E-Mail-Adresse posten würden.
# Senden Sie diese an eine beliebige Person in einer privaten E-Mail, damit diese sie beim wiederholten Senden von Dateien an Sie verwenden kann.
# Sie können Ihren Filedrop-Link erhalten, indem Sie in den Bereich Konto wechseln.
# Es sieht ungefähr so ​​aus: Sie sehen zwei Links, einen zufälligen und einen mit Ihrer E-Mail-Adresse.
# Der zufällige Link ist ein Link, der nicht erraten werden kann. Es ist also sicherer, an Orten zu posten, an denen Sie nicht sicher sind, ob Sie Ihre E-Mail-Adresse teilen möchten.
# Sollte der Link jemals in die falschen Hände geraten, können Sie jederzeit zu dieser Seite zurückkehren und auf die Schaltfläche "Reset Filedrop URL" klicken.
# Dadurch wird eine neue zufällige Filedrop-URL für Sie generiert.
# Beachten Sie, dass dadurch Ihre vorherige URL automatisch ungültig wird, sodass jeder, der versucht, die vorherige URL zu verwenden, die Meldung 404 Seite nicht gefunden erhält.
# Der Link mit Ihrer E-Mail sieht besser aus und lässt sich leichter überprüfen, wenn jemand ihn eingeben muss.
# Dieser Link läuft jedoch niemals ab (es sei denn, Sie ändern die E-Mail-Adresse).
# Wenn jemand Ihre Filedrop-URL besucht (in diesem Beispiel https://liquidfiles.company.com/filedrop/~VZ209z), sieht er eine Seite wie die folgende: Jeder, der diese Seite besucht, kann Ihnen Dateien senden, indem er sie ausfüllt Klicken Sie in allen Feldern auf die Schaltfläche "Dateien hinzufügen" und dann auf "Senden".
# Bitte beachten Sie, dass es kein "An" -Feld gibt.
# Da dies Ihre Filedrop-URL ist, werden Ihnen immer alle hier gesendeten Dateien zugestellt.
# FileLinks Mit FileLinks können Sie auf einfache Weise Links zu einzelnen Dateien senden. FileLinks sind direkte Links zu Dateien.
# Der primäre Anwendungsfall besteht darin, Links zu Dateien senden zu können, wenn Sie den Empfänger nicht unbedingt vorher kennen oder einfach nur etwas schnelles und einfaches wollen.
# Es eignet sich auch hervorragend zum Posten von Links in Online-Foren, in Instant Messaging-Apps usw.
# Die FileLink-Oberfläche erreichen Sie durch Auswahl von FileLink in der Menüleiste.
# Die Hauptschnittstelle von FileLink sieht folgendermaßen aus, mit den folgenden Optionen.
# Die Registerkarte zum Erstellen neuer FileLinks.
# Die Registerkarte zum Auflisten vorhandener Dateilinks.
# Auf der Registerkarte werden die verfügbaren Dateien aufgelistet, sodass Sie FileLinks erstellen können, ohne neue Dateien hochladen zu müssen.
# Auswählen einer neuen Datei zum Erstellen des FileLink.
# Erstellen des FileLink, nachdem die Datei ausgewählt wurde.
# Einschränkungen in Bezug auf Dateigröße und Dateityp werden hier aufgelistet.
# Erstellen eines FileLinks Bei der Auswahl einer Datei haben Sie folgende Möglichkeiten.
# Die ausgewählte Datei mit Dateigröße und Entfernen-Schaltfläche.
# Wenn der FileLink abläuft.
# Nach diesem Datum kann niemand mehr auf FileLink zugreifen.
# Wenn diese Option aktiviert ist, erhalten Sie nach jedem Download des FileLink eine Bestätigungs-E-Mail.
# Wenn diese Option aktiviert ist, muss sich jeder Benutzer authentifizieren, bevor er auf FileLink zugreift.
# Wenn der Benutzer kein Konto im LiquidFiles-System hat, authentifiziert er sich mit seiner E-Mail-Adresse.
# Wenn Sie fertig sind, erstellen Sie einen Link, um den FileLink zu erstellen.
# Die FileLink-Seite Wenn ein Benutzer den FileLink besucht, wird die folgende Seite angezeigt.
# Die Dateidetails, einschließlich Dateiname, Dateigröße und SHA-256-Prüfsumme.
# Der Download-Button.
# Wenn Sie eine Ihrer eigenen FileLink-Seiten besuchen, wird die folgende Seite angezeigt.
# Die Dateidetails, einschließlich Dateiname, Dateigröße und SHA-256-Prüfsumme (wie bei jedem anderen Benutzer).
# Die Download-Schaltfläche (wie jeder andere Benutzer auch).
# Das FileLink-Ablaufdatum.
# Durch Klicken auf die Schaltfläche "FileLink in Zwischenablage kopieren" wird die URL in den FileLink in die Zwischenablage kopiert.
# Ein- und Ausschalten der Download-Belege.
# Aktivieren oder deaktivieren Sie die Option Authentifizierung erforderlich.
# Mit der Funktion "FileLink in Zwischenablage kopieren" können Sie den FileLink jetzt in eine Chat-Nachricht kopieren, in einem Forum veröffentlichen, in SharePoint veröffentlichen oder an einer anderen Stelle, an der Sie diese Datei verfügbar machen möchten.
# Plug-ins mit dem Outlook-Plug-in Wenn Ihr Administrator das Outlook-Plug-in installiert und aktiviert hat, wird beim Verfassen einer Nachricht in Outlook ein zusätzlicher Abschnitt angezeigt. Dies sind die auswählbaren Optionen im Dropdown-Menü LiquidFiles Secure Attach: Secure Anhängen - Jede Datei, die Sie normalerweise mit dem Symbol "Anhängen" in Outlook anhängen würden, kann stattdessen über diese Schaltfläche "Sicheres Anhängen" angehängt werden.
# Dadurch werden alle an die E-Mail angehängten Dateien mit LiquidFiles gesendet.
# Ordner anhängen - Sie können auch einen Ordner anhängen, und alle Dateien in diesem Ordner werden an diese E-Mail angehängt.
# Secure Attach All - Das Outlook-Plugin sendet automatisch große Dateien über LiquidFiles.
# Wenn Sie eine Kombination aus größeren und kleineren Anhängen haben, bedeutet dies, dass einige LiquidFiles durchlaufen und andere direkt.
# Durch Auswahl von Secure Attach All werden alle großen und kleinen Dateien über LiquidFiles gesendet.
# Dateianforderung - Verwenden Sie LiquidFiles, um eine große und / oder vertrauliche Datei von jemandem anzufordern.
# Der Empfänger der Dateianforderung erhält einen Link, den er verwenden kann, und alle angehängten Dateien werden sicher an Sie zurückgesandt.
# Private Nachricht - Dadurch wird der Text der E-Mail mit oder ohne Anhänge sicher über LiquidFiles gesendet.
# Sie erhalten eine Bestätigung, wenn jemand Ihre E-Mail geöffnet und Anhänge heruntergeladen hat.
# Vorhandene Dateien auswählen - Hier werden bereits hochgeladene Dateien aus früheren Nachrichten aufgelistet, die Sie erneut senden können, ohne dass Sie sie hochladen müssen.
# Optionen - Konfigurieren Sie das LiquidFiles Outlook-Plugin.
# Senden einer Datei über LiquidFiles Wenn Sie eine Datei zum Anhängen und Senden über LiquidFiles ausgewählt haben, wird ein anderes Fenster geöffnet: Hier sehen Sie die angehängte Datei mit einigen grundlegenden Einstellungen für diese Nachricht.
# Weitere Einstellungen finden Sie in der Multifunktionsleiste: Oder als Nahaufnahme: In der oberen Multifunktionsleiste sehen Sie die LiquidFiles-Einstellungen für diese Nachricht von oben links: Sie können diese Nachricht senden, für deren Zugriff eine Authentifizierung erforderlich ist.
# Sie können diese Nachricht als private Nachricht senden (wenn der Text der E-Mail privat über LiquidFiles gesendet wird).
# Sie können die Zugriffsberechtigung so auswählen, wie Sie es auf der Weboberfläche sehen würden.
# Auf dem Screenshot wird "Nur angegebene Empfänger können zugreifen" angezeigt.
# Wie oft kann jeder Empfänger eine Datei herunterladen?
# Wann läuft die Nachricht ab?
# Outlook-Einstellungen und -Konfiguration Wenn Sie Ihre erste Datei an LiquidFiles anhängen, wird das Anmeldefenster angezeigt: Dieses Fenster enthält die LiquidFiles-Serveradresse, falls das Plugin eine Verbindung mit http, https oder automatisch erkennen soll, sowie Ihren Benutzernamen und Ihr Kennwort.
# Der Benutzername und das Kennwort stimmen mit dem Benutzernamen und dem Kennwort überein, mit dem Sie sich bei der LiquidFiles-Weboberfläche angemeldet haben.
# Bitte beachten Sie, dass Sie dies nur einmal ausfüllen müssen und das LiquidFiles Outlook-Plugin Sie auch dann eingeloggt hält, wenn Sie Ihr Netzwerkkennwort ändern.
# Das Einstellungsfenster sieht folgendermaßen aus: Es enthält die folgenden konfigurierbaren Einstellungen von oben: Es zeigt den aktuell angemeldeten Benutzer an.
# Wie viele Dateien können Sie auf einmal anhängen und wie lange soll das Fenster angezeigt werden, nachdem Sie die Dateien gesendet haben.
# Wo sollen die LiquidFiles-Anhangsinformationen abgelegt werden? (Informationen zum Aussehen der Anhangsinformationen finden Sie in der E-Mail des Empfängers.)
# Senden Sie die Nachricht mit HTML oder einfachem Text oder senden Sie keine Nachricht über LiquidFiles.
# Mit den Einstellungen zum automatischen Senden von Anhängen über einer bestimmten Größe werden Dateien an LiquidFiles angehängt, unabhängig davon, ob Sie auf den "normalen" Anhang oder auf die Schaltfläche zum sicheren Anhängen geklickt haben, wenn die Datei über dieser Größe liegt.
